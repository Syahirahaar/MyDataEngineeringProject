# %% [markdown]
# ## Checking the original file's cleanliness

# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/Syahirahar/Documents/GitHub/MyDataEngineeringProject/Invistico_Airline.csv')
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#             id satisfaction  Gender   Customer Type   Age   Type of Travel  \
# 0  212-12-2276    satisfied  Female  Loyal Customer  65.0  Personal Travel
# 1  304-60-7707    satisfied    Male  Loyal Customer  47.0  Personal Travel
# 2  832-31-5861    satisfied  Female  Loyal Customer  15.0  Personal Travel
# 3  650-80-4379    satisfied  Female  Loyal Customer  60.0  Personal Travel
# 4  721-02-2779    satisfied  Female  Loyal Customer  70.0  Personal Travel
#
#       Class  Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 0       Eco            265.0           0.0                                0.0
# 1  Business           2464.0           0.0                                0.0
# 2       Eco           2138.0           0.0                                0.0
# 3       Eco            623.0           0.0                                0.0
# 4       Eco            354.0           0.0                                0.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129881 entries, 0 to 129880
# Data columns (total 27 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   id                                 129881 non-null  object
#  1   satisfaction                       129880 non-null  object
#  2   Gender                             129880 non-null  object
#  3   Customer Type                      129880 non-null  object
#  4   Age                                129880 non-null  float64
#  5   Type of Travel                     129880 non-null  object
#  6   Class                              129880 non-null  object
#  7   Flight Distance                    129880 non-null  float64
#  8   Seat comfort                       129880 non-null  float64
#  9   Departure/Arrival time convenient  129880 non-null  float64
#  10  Food and drink                     129880 non-null  float64
# ...

# %%
df.columns
# Out:
# Index(['id', 'satisfaction', 'Gender', 'Customer Type', 'Age',
#        'Type of Travel', 'Class', 'Flight Distance', 'Seat comfort',
#        'Departure/Arrival time convenient', 'Food and drink', 'Gate location',
#        'Inflight wifi service', 'Inflight entertainment', 'Online support',
#        'Ease of Online booking', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Cleanliness', 'Online boarding',
#        'Departure Delay in Minutes', 'Arrival Delay in Minutes', 'Timestamp',
#        'Code', 'Location'],
#       dtype='object')

# %%
df = df[['satisfaction', 'Customer Type', 'Age',
       'Type of Travel', 'Class', 'Flight Distance', 'Seat comfort',
       'Departure/Arrival time convenient', 'Food and drink', 'Gate location',
       'Inflight wifi service', 'Inflight entertainment', 'Online support',
       'Ease of Online booking', 'On-board service', 'Leg room service',
       'Baggage handling', 'Checkin service', 'Cleanliness', 'Online boarding',
       'Departure Delay in Minutes', 'Arrival Delay in Minutes', 'Timestamp',
       'Code', 'Location']]

# %%
(df.duplicated().value_counts()/df.shape[0])*100
# Out:
# False    100.0
# dtype: float64

# %% [markdown]
# ## Merge ori and fake_generated_data

# %%
airline_data = df

# %%
fake_data = pd.read_csv('C:/Users/Syahirahar/Documents/GitHub/MyDataEngineeringProject/generate_fake_data.csv')

# %%
result = pd.concat([airline_data,fake_data], axis=1)

# %%
result.head()
# Out:
#   satisfaction   Customer Type   Age   Type of Travel     Class  \
# 0    satisfied  Loyal Customer  65.0  Personal Travel       Eco
# 1    satisfied  Loyal Customer  47.0  Personal Travel  Business
# 2    satisfied  Loyal Customer  15.0  Personal Travel       Eco
# 3    satisfied  Loyal Customer  60.0  Personal Travel       Eco
# 4    satisfied  Loyal Customer  70.0  Personal Travel       Eco
#
#    Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 0            265.0           0.0                                0.0
# 1           2464.0           0.0                                0.0
# 2           2138.0           0.0                                0.0
# 3            623.0           0.0                                0.0
# 4            354.0           0.0                                0.0
#
#    Food and drink  Gate location  Inflight wifi service  \
# 0             0.0            2.0                    2.0
# ...

# %%
result.columns
# Out:
# Index(['satisfaction', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Seat comfort', 'Departure/Arrival time convenient',
#        'Food and drink', 'Gate location', 'Inflight wifi service',
#        'Inflight entertainment', 'Online support', 'Ease of Online booking',
#        'On-board service', 'Leg room service', 'Baggage handling',
#        'Checkin service', 'Cleanliness', 'Online boarding',
#        'Departure Delay in Minutes', 'Arrival Delay in Minutes', 'Timestamp',
#        'Code', 'Location', 'Unnamed: 0', 'customer_id', 'flight_id',
#        'review_id', 'timestamp', 'Names', 'gender', 'destination'],
#       dtype='object')

# %%
final_result = result[['customer_id','review_id','flight_id','Names','gender','Customer Type', 'Age',
       'Type of Travel', 'Class', 'Flight Distance', 'Seat comfort',
       'Departure/Arrival time convenient', 'Food and drink', 'Gate location',
       'Inflight wifi service', 'Inflight entertainment', 'Online support',
       'Ease of Online booking', 'On-board service', 'Leg room service',
       'Baggage handling', 'Checkin service', 'Cleanliness', 'Online boarding',
       'Departure Delay in Minutes', 'Arrival Delay in Minutes', 'Timestamp',

       'destination']]

# %%
final_result = final_result.rename({'Type of Travel':'type_of_travel','Customer Type':'cust_type','Flight Distance':'flight_distance','Seat comfort':'seat_comfort',
                            'Departure/Arrival time convenient' : 'deptarrive_time_convenient', 'Food and drink':'food_drink', 'Gate location':'gate_location',
       'Inflight wifi service': 'inflight_wifi', 'Inflight entertainment' : 'inflight_ent', 'Online support' :'online_support',
       'Ease of Online booking': 'easy_online_booking', 'On-board service':'onboard_service', 'Leg room service': 'legroom',
       'Baggage handling': 'baggage_handling', 'Checkin service' : 'checking_service', 'Cleanliness':'cleanliness', 'Online boarding' : 'online_boarding',
       'Departure Delay in Minutes': 'dept_delay_min', 'Arrival Delay in Minutes': 'arrival_delay_min'}, axis = 1)

# %%
final_result.head()
# Out:
#    customer_id  review_id flight_id           Names gender       cust_type  \
# 0  294-93-0685     128195     S0685       Loran Von      M  Loyal Customer
# 1  728-97-2565     122231     S2565    Elana Beatty      F  Loyal Customer
# 2  600-21-7300     126402     S7300  Danita Corkery      M  Loyal Customer
# 3  114-56-6256     125491     S6256   Herminia Mann      M  Loyal Customer
# 4  016-56-9671        784     S9671  Meryl Emmerich      M  Loyal Customer
#
#     Age   type_of_travel     Class  flight_distance  seat_comfort  \
# 0  65.0  Personal Travel       Eco            265.0           0.0
# 1  47.0  Personal Travel  Business           2464.0           0.0
# 2  15.0  Personal Travel       Eco           2138.0           0.0
# 3  60.0  Personal Travel       Eco            623.0           0.0
# 4  70.0  Personal Travel       Eco            354.0           0.0
#
#    deptarrive_time_convenient  food_drink  gate_location  inflight_wifi  \
# ...

# %%
final_result.dtypes
# Out:
# customer_id                    object
# review_id                       int64
# flight_id                      object
# Names                          object
# gender                         object
# cust_type                      object
# Age                           float64
# type_of_travel                 object
# Class                          object
# flight_distance               float64
# seat_comfort                  float64
# deptarrive_time_convenient    float64
# food_drink                    float64
# gate_location                 float64
# inflight_wifi                 float64
# inflight_ent                  float64
# online_support                float64
# easy_online_booking           float64
# onboard_service               float64
# legroom                       float64
# baggage_handling              float64
# checking_service              float64
# cleanliness                   float64
# online_boarding               float64
# dept_delay_min                float64
# ...

# %%
final_result.to_csv('final_result.csv')
