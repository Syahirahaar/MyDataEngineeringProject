# %%
import pandas as pd

a = pd.read_csv('sample_final.csv')
a.head()
# Out:
#     customerid  review_id flight_id              names gender   customer_type  \
# 0  331-18-2844      88976     S2844        Loy Waelchi      F  Loyal Customer
# 1  264-61-9134      18213     S9134  Venice Konopelski      F  Loyal Customer
# 2  637-49-6833       4312     S6833         Dori Yundt      M  Loyal Customer
# 3  191-03-7238      33150     S7238       Cesar Hansen      M  Loyal Customer
# 4  452-05-6438      61568     S6438   Eulalia Mosciski      M  Loyal Customer
#
#    age   type_of_travel     class  flight_distance  ...  onboard_service  \
# 0   31  Business travel  Business             3583  ...                5
# 1   60  Business travel       Eco             2167  ...                2
# 2   39  Personal Travel  Eco Plus             1408  ...                4
# 3   66  Personal Travel       Eco              623  ...                5
# 4   28  Personal Travel  Eco Plus             1444  ...                3
#
# ...

# %%
a.columns
# Out:
# Index(['customerid', 'review_id', 'flight_id', 'names', 'gender',
#        'customer_type', 'age', 'type_of_travel', 'class', 'flight_distance',
#        'seat_comfort', 'deptarrive_time_convenient', 'food_drink',
#        'gate_location', 'inflight_wifi', 'inflight_entertainment',
#        'online_support', 'ease_online_booking', 'onboard_service',
#        'legroom_service', 'baggage_handling', 'checkin_service', 'cleanliness',
#        'online_boarding', 'dept_delay_min', 'arrival_delay_min', 'timestamp',
#        'destination'],
#       dtype='object')
